# %%
#question 1:
name="mehul"
age=20
height=69 #inches
print(f"Name is:{name},{type(name)}")
print("age is:",age,type(age))
print("height is:",height,("in inches"),type(height))
# Out:
# Name is:mehul,<class 'str'>
# age is: 20 <class 'int'>
# height is: 69 in inches <class 'int'>

# %%
#question 2
num=str(input("enter first number"))
num2=str(input("enter second number"))
print(int(num)+int(num2))
# Out:
# 90

# %%
#question 3
age=int(input("please enter your age:"))
if age>=18:
    print("you are eligible to vote")
else:
    print ("you are underage to vote")

# without (if, else) way:
# is_eligible= age>=18
# print(is_eligible)
# Out:
# you are eligible to vote
